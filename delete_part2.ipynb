# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshBjeeffy/Pandas/blob/master/delete_part2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = pd.read_csv(url)
iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# #Create columns for the dataset

# %%
iris.columns = ['sepal_length','sepal_width', 'petal_length', 'petal_width', 'class']
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %%
#null values
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %% [markdown]
# #Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.iloc[10:30,2:3] = np.nan
iris.head(20)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            4.9          3.0           1.4          0.2  Iris-setosa
# 1            4.7          3.2           1.3          0.2  Iris-setosa
# 2            4.6          3.1           1.5          0.2  Iris-setosa
# 3            5.0          3.6           1.4          0.2  Iris-setosa
# 4            5.4          3.9           1.7          0.4  Iris-setosa
# 5            4.6          3.4           1.4          0.3  Iris-setosa
# 6            5.0          3.4           1.5          0.2  Iris-setosa
# 7            4.4          2.9           1.4          0.2  Iris-setosa
# 8            4.9          3.1           1.5          0.1  Iris-setosa
# 9            5.4          3.7           1.5          0.2  Iris-setosa
# 10           4.8          3.4           NaN          0.2  Iris-setosa
# 11           4.8          3.0           NaN          0.1  Iris-setosa
# ...

# %% [markdown]
# # Good, now lets substitute the NaN values to 1.0

# %%
iris.petal_length.fillna(1.0,inplace=True)
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width           class
# 0             4.9          3.0           1.4          0.2     Iris-setosa
# 1             4.7          3.2           1.3          0.2     Iris-setosa
# 2             4.6          3.1           1.5          0.2     Iris-setosa
# 3             5.0          3.6           1.4          0.2     Iris-setosa
# 4             5.4          3.9           1.7          0.4     Iris-setosa
# 5             4.6          3.4           1.4          0.3     Iris-setosa
# 6             5.0          3.4           1.5          0.2     Iris-setosa
# 7             4.4          2.9           1.4          0.2     Iris-setosa
# 8             4.9          3.1           1.5          0.1     Iris-setosa
# 9             5.4          3.7           1.5          0.2     Iris-setosa
# 10            4.8          3.4           1.0          0.2     Iris-setosa
# 11            4.8          3.0           1.0          0.1     Iris-setosa
# ...

# %%
#delete the column class
del[iris["class"]]
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           4.9          3.0           1.4          0.2
# 1           4.7          3.2           1.3          0.2
# 2           4.6          3.1           1.5          0.2
# 3           5.0          3.6           1.4          0.2
# 4           5.4          3.9           1.7          0.4

# %%
#Set the first 3 rows as NaN
iris.iloc[0:3,:]=np.nan
iris.head()
# Out:
#    index  sepal_length  sepal_width  petal_length  petal_width
# 0    NaN           NaN          NaN           NaN          NaN
# 1    NaN           NaN          NaN           NaN          NaN
# 2    NaN           NaN          NaN           NaN          NaN
# 3    3.0           5.0          3.4           1.5          0.2
# 4    4.0           4.4          2.9           1.4          0.2

# %% [markdown]
# #Delete the rows that have NaN

# %%
iris=iris.dropna(how="any")
iris.head()
# Out:
#    index  sepal_length  sepal_width  petal_length  petal_width
# 3    3.0           5.0          3.4           1.5          0.2
# 4    4.0           4.4          2.9           1.4          0.2
# 5    5.0           4.9          3.1           1.5          0.1
# 6    6.0           5.4          3.7           1.5          0.2
# 7    7.0           5.4          3.4           1.5          0.4

# %%
#Reset the index so it begins with 0 again
iris=iris.reset_index()
iris.head()
# Out:
#    level_0  index  sepal_length  sepal_width  petal_length  petal_width
# 0        3    3.0           5.0          3.4           1.5          0.2
# 1        4    4.0           4.4          2.9           1.4          0.2
# 2        5    5.0           4.9          3.1           1.5          0.1
# 3        6    6.0           5.4          3.7           1.5          0.2
# 4        7    7.0           5.4          3.4           1.5          0.4
