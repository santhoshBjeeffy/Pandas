# %% [markdown]
# <a href="https://colab.research.google.com/github/santhoshBjeeffy/Pandas/blob/master/Applypart2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv"
crime = pd.read_csv(url)
crime.head()
# Out:
#    Year  Population    Total  ...  Burglary  Larceny_Theft  Vehicle_Theft
# 0  1960   179323175  3384200  ...    912100        1855400         328200
# 1  1961   182992000  3488000  ...    949600        1913000         336000
# 2  1962   185771000  3752200  ...    994300        2089600         366800
# 3  1963   188483000  4109500  ...   1086400        2297800         408300
# 4  1964   191141000  4564600  ...   1213200        2514400         472800
#
# [5 rows x 12 columns]

# %%
#what is the type of colum?
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
# Year                  55 non-null int64
# Population            55 non-null int64
# Total                 55 non-null int64
# Violent               55 non-null int64
# Property              55 non-null int64
# Murder                55 non-null int64
# Forcible_Rape         55 non-null int64
# Robbery               55 non-null int64
# Aggravated_assault    55 non-null int64
# Burglary              55 non-null int64
# Larceny_Theft         55 non-null int64
# Vehicle_Theft         55 non-null int64
# dtypes: int64(12)
# memory usage: 5.2 KB

# %%
#Convert the type of the column Year to datetime64
#pd.to_datetime(crime)
crime.Year=pd.to_datetime(crime.Year,format='%Y')
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
# Year                  55 non-null datetime64[ns]
# Population            55 non-null int64
# Total                 55 non-null int64
# Violent               55 non-null int64
# Property              55 non-null int64
# Murder                55 non-null int64
# Forcible_Rape         55 non-null int64
# Robbery               55 non-null int64
# Aggravated_assault    55 non-null int64
# Burglary              55 non-null int64
# Larceny_Theft         55 non-null int64
# Vehicle_Theft         55 non-null int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.2 KB

# %%
crime.head()
# Out:
#         Year  Population    Total  ...  Burglary  Larceny_Theft  Vehicle_Theft
# 0 1960-01-01   179323175  3384200  ...    912100        1855400         328200
# 1 1961-01-01   182992000  3488000  ...    949600        1913000         336000
# 2 1962-01-01   185771000  3752200  ...    994300        2089600         366800
# 3 1963-01-01   188483000  4109500  ...   1086400        2297800         408300
# 4 1964-01-01   191141000  4564600  ...   1213200        2514400         472800
#
# [5 rows x 12 columns]

# %%
#set the year as index
crime=crime.set_index('Year', drop = True)
crime.head()
# Out:
#             Population    Total  ...  Larceny_Theft  Vehicle_Theft
# Year                             ...
# 1960-01-01   179323175  3384200  ...        1855400         328200
# 1961-01-01   182992000  3488000  ...        1913000         336000
# 1962-01-01   185771000  3752200  ...        2089600         366800
# 1963-01-01   188483000  4109500  ...        2297800         408300
# 1964-01-01   191141000  4564600  ...        2514400         472800
#
# [5 rows x 11 columns]

# %%
#delete the total column

# %%
del crime['Total']
crime.head()
# Out:
#             Population  Violent  ...  Larceny_Theft  Vehicle_Theft
# Year                             ...
# 1960-01-01   179323175   288460  ...        1855400         328200
# 1961-01-01   182992000   289390  ...        1913000         336000
# 1962-01-01   185771000   301510  ...        2089600         366800
# 1963-01-01   188483000   316970  ...        2297800         408300
# 1964-01-01   191141000   364220  ...        2514400         472800
#
# [5 rows x 10 columns]

# %% [markdown]
# #Group the year by decades and sum the values

# %%
crimes=crime.resample('10AS').sum()

#use resample to get the maximum value only for the "population column"
population=crime['Population'].resample('10AS').max()

#updating the population column
crime['Population']=population

crimes
# Out:
#             Population   Violent  ...  Larceny_Theft  Vehicle_Theft
# Year                              ...
# 1960-01-01  1915053175   4134930  ...       26547700        5292100
# 1970-01-01  2121193298   9607930  ...       53157800        9739900
# 1980-01-01  2371370069  14074328  ...       72040253       11935411
# 1990-01-01  2612825258  17527048  ...       77679366       14624418
# 2000-01-01  2947969117  13968056  ...       67970291       11412834
# 2010-01-01  1570146307   6072017  ...       30401698        3569080
#
# [6 rows x 10 columns]

# %%
#What is the mos dangerous decade to live in the US?
## apparently the 90s was a pretty dangerous time in the US
crime.idxmax(0)
# Out:
# Population           2010-01-01
# Violent              1992-01-01
# Property             1991-01-01
# Murder               1991-01-01
# Forcible_Rape        1992-01-01
# Robbery              1991-01-01
# Aggravated_assault   1993-01-01
# Burglary             1980-01-01
# Larceny_Theft        1991-01-01
# Vehicle_Theft        1991-01-01
# dtype: datetime64[ns]
